# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
data=pd.read_csv("Processed_DJI.csv")
data1=pd.DataFrame(data)
data1
# Out:
#             Date         Close     Volume       mom      mom1      mom2  \
# 0     2009-12-31  10428.049805        NaN       NaN       NaN       NaN
# 1     2010-01-04  10583.959961        NaN  0.014951       NaN       NaN
# 2     2010-01-05  10572.019531        NaN -0.001128  0.014951       NaN
# 3     2010-01-06  10573.679688   0.515598  0.000157 -0.001128  0.014951
# 4     2010-01-07  10606.860352   9.776045  0.003138  0.000157 -0.001128
# ...          ...           ...        ...       ...       ...       ...
# 1979  2017-11-09  23461.939453   6.511740 -0.004304  0.000260  0.000374
# 1980  2017-11-10  23422.210938  -0.991838 -0.001693 -0.004304  0.000260
# 1981  2017-11-13  23439.699219 -65.347705  0.000747 -0.001693 -0.004304
# 1982  2017-11-14  23409.470703  -1.387911 -0.001290  0.000747 -0.001693
# 1983  2017-11-15  23271.279297   3.612171 -0.005903 -0.001290  0.000747
#
#           mom3     ROC_5    ROC_10    ROC_15  ...   NZD  silver-F  RUSSELL-F  \
# ...

# %%
data1.drop(data1.iloc[:, 25:], inplace=True, axis=1)
data1
# Out:
#             Date         Close     Volume       mom      mom1      mom2  \
# 0     2009-12-31  10428.049805        NaN       NaN       NaN       NaN
# 1     2010-01-04  10583.959961        NaN  0.014951       NaN       NaN
# 2     2010-01-05  10572.019531        NaN -0.001128  0.014951       NaN
# 3     2010-01-06  10573.679688   0.515598  0.000157 -0.001128  0.014951
# 4     2010-01-07  10606.860352   9.776045  0.003138  0.000157 -0.001128
# ...          ...           ...        ...       ...       ...       ...
# 1979  2017-11-09  23461.939453   6.511740 -0.004304  0.000260  0.000374
# 1980  2017-11-10  23422.210938  -0.991838 -0.001693 -0.004304  0.000260
# 1981  2017-11-13  23439.699219 -65.347705  0.000747 -0.001693 -0.004304
# 1982  2017-11-14  23409.470703  -1.387911 -0.001290  0.000747 -0.001693
# 1983  2017-11-15  23271.279297   3.612171 -0.005903 -0.001290  0.000747
#
#           mom3     ROC_5    ROC_10    ROC_15  ...  DTB4WK  DTB3  DTB6  DGS5  \
# ...

# %%
data1.dropna(axis=1, inplace=True)
data1
# Out:
#             Date         Close  DTB4WK  DTB3  DTB6  DGS5  DGS10  DAAA  DBAA
# 0     2009-12-31  10428.049805    0.04  0.06  0.20  2.69   3.85  5.33  6.39
# 1     2010-01-04  10583.959961    0.05  0.08  0.18  2.65   3.85  5.35  6.39
# 2     2010-01-05  10572.019531    0.03  0.07  0.17  2.56   3.77  5.24  6.30
# 3     2010-01-06  10573.679688    0.03  0.06  0.15  2.60   3.85  5.30  6.34
# 4     2010-01-07  10606.860352    0.02  0.05  0.16  2.62   3.85  5.31  6.33
# ...          ...           ...     ...   ...   ...   ...    ...   ...   ...
# 1979  2017-11-09  23461.939453    1.05  1.22  1.33  2.01   2.33  3.60  4.26
# 1980  2017-11-10  23422.210938    1.03  1.21  1.34  2.06   2.40  0.00  0.00
# 1981  2017-11-13  23439.699219    1.04  1.22  1.35  2.08   2.40  3.69  4.33
# 1982  2017-11-14  23409.470703    1.04  1.24  1.37  2.06   2.38  3.66  4.31
# 1983  2017-11-15  23271.279297    1.06  1.23  1.36  2.04   2.33  3.60  4.28
#
# [1984 rows x 9 columns]

# %% [markdown]
# Pair Plot

# %%
import matplotlib.pyplot as plt
import seaborn as s
s.pairplot(data1)
plt.show(data1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 4
#       2 import seaborn as s
#       3 s.pairplot(data1)
# ----> 4 plt.show(data1)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib_inline\backend_inline.py:98, in show(close, block)
#      95 show._to_draw = []
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
# ---> 98 if close and Gcf.get_all_fig_managers():
#      99     matplotlib.pyplot.close('all')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
# ...

# %% [markdown]
# Using Library Functions

# %%
X = data1['DTB3'].values
y = data1["DTB6"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# %%
model = LinearRegressionManual()
model.fit(X_train, y_train)

# %%
intercept, coefficient = model.intercept_, model.coef_

# %%
predictions = model.predict(X)

# %%
print(f"Intercept: {intercept},\nCoefficient: {coefficient},\nPredictions: {predictions}")
# Out:
# Intercept: 0.055115815276622404,
# Coefficient: 1.0802989687385192,
# Predictions: [0.11993375 0.14153973 0.13073674 ... 1.37308056 1.39468654 1.38388355]

# %%
plt.scatter(X, y, color='blue', label='Data points')
plt.plot(X, predictions, color='red', label='Regression Line')
plt.xlabel('Independent variable X')
plt.ylabel('Dependent variable y')
plt.title('Linear Regression Model')
plt.legend()
plt.show()

# %% [markdown]
# Using User-Defined Functions

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Processed_DJI.csv')

# %%
X2 = dataset['DTB3'].values
y2 = dataset['DTB6'].values

# %%
denominator = X2.dot(X2) - X2.mean() * X2.sum()
m2 = (X2.dot(y2) - y2.mean() * X2.sum()) / denominator
b2 = (y2.mean() * X2.dot(X2) - X2.mean() * X2.dot(y2)) / denominator
y_pred = m2 * X2 + b2

# %%
plt.scatter(X2, y2, color='blue', label='Scatter Plot')
plt.plot(X2, y_pred, color='red', label='Regression Line')
plt.title('Linear Regression')
plt.xlabel('X2')
plt.ylabel('Y2')
plt.legend()
plt.grid(True)
plt.show()
